# %%
import re
import matplotlib.pyplot as plt
loss = [0.1812, 0.0131, 0.0123, 0.0116, 0.0114, 0.0114, 0.0113, 0.0111, 0.0110, 0.0110, 0.0111, 0.0110, 0.0108, 0.0111, 0.0109, 0.0109, 0.0108, 0.0108, 0.0107, 0.0108, 0.0107, 0.0108, 0.0109, 0.0110, 0.0108, 0.0108]
iou = [0.5707, 0.9710, 0.9726, 0.9739, 0.9741, 0.9743, 0.9744, 0.9751, 0.9753, 0.9754,0.9746, 0.9754, 0.9756, 0.9758, 0.9758, 0.9757, 0.9762, 0.9760, 0.9762, 0.9761, 0.9763, 0.9762, 0.9760, 0.9760, 0.9762, 0.9762]

#loss = [0.0107, 0.0029, 0.0027, 0.0026, 0.0026, 0.0025, 0.0025, 0.0024, 0.0025, 0.0024, 0.0025, 0.0025, 0.0026, 0.0024, 0.0025, 0.0025, 0.0025, 0.0025, 0.0025]
#iou = [0.8414, 0.9488, 0.9522, 0.9532, 0.9529, 0.9551, 0.9542, 0.9559, 0.9549, 0.9546, 0.9554, 0.9550, 0.9546, 0.9567, 0.9563, 0.9570, 0.9564, 0.9564, 0.9564]

# Simulated x-axis: each value corresponds to an index (e.g. checkpoint number)
epochs = list(range(1, len(loss) + 1))

# Create figure and axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot Loss
color = 'tab:red'
ax1.set_xlabel('Epoch Number')
ax1.set_ylabel('Validation Loss', color=color)
ax1.plot(epochs, loss, marker='o', color=color, label='Validation Loss')
ax1.tick_params(axis='y', labelcolor=color)
#ax1.legend(loc='upper left')

# Plot IoU on a second y-axis
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('IoU', color=color)
ax2.plot(epochs, iou, marker='x', linestyle='--', color=color, label='IoU')
ax2.tick_params(axis='y', labelcolor=color)
#ax2.legend(loc='upper right')

# Title and grid
plt.title('Mature SAM Training – Validation Loss and IoU over Epochs')
plt.grid(True)
plt.tight_layout()

plt.savefig('sam_training_plot.png', dpi=300)

# Show plot
plt.show()

# %%
from ultralytics import YOLO

# Load your trained YOLOv11 model
model = YOLO(r"C:\Users\richa_0\Documents\Coral Recruit Research\Machine Learning Models\V2 Models\2733-augmented-adjusted.yolov11\results\50_epochs-\weights\best.pt")

# Run validation on the test set
metrics = model.val(
    data=r"C:\Users\richa_0\Documents\Coral Recruit Research\Machine Learning Models\V2 Models\2733-augmented-adjusted.yolov11\data.yaml",
    split='test'
)

# Print the summary of test results
print(metrics)
# Out:
# Ultralytics 8.3.59  Python-3.12.8 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning C:\Users\richa_0\Documents\Coral Recruit Research\Machine Learning Models\V2 Models\2733-augmented-adjusted.yolov11\test\labels... 417 images, 0 backgrounds, 0 corrupt: 100%|██████████| 417/417 [00:00<00:00, 540.28it/s]
# val: New cache created: C:\Users\richa_0\Documents\Coral Recruit Research\Machine Learning Models\V2 Models\2733-augmented-adjusted.yolov11\test\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 27/27 [00:05<00:00,  5.39it/s]
#                    all        417        417      0.972      0.986      0.993      0.911
#         early-recruits        208        208      0.971      0.986      0.992      0.873
# ...
